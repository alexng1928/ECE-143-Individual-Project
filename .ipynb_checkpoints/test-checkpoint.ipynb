# %%
from TowerClass import Tower
from Modules import create_rand_tower, create_max, trim

a = Tower((0,0),3,3)
b = Tower((1,1),4,4)
c = Tower((4,1),2,1)
d = Tower((1,4),1,2)
print a
print b
print c
# Out:
# Starting Coord:(0, 0), Width :3, Height:3
# Starting Coord:(1, 1), Width :4, Height:4
# Starting Coord:(4, 1), Width :2, Height:1

# %%
temp = create_max(c,[a])
print temp
# Out:
# Starting Coord:(4, 1), Width :2, Height:1

# %%
# %matplotlib notebook
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import time

fig,ax = plt.subplots(1)
plt.axis([0,10,0,10])
rect = patches.Rectangle(a.start_coord, a.width, a.height, fc='r', alpha=0.5)
rect2 = patches.Rectangle(b.start_coord, b.width, b.height, alpha=0.5)
rect3 = patches.Rectangle(c.start_coord, c.width, c.height, alpha=0.5)
rects = [rect, rect2, rect3]

for i in rects:
    ax.add_patch(i)
    fig.canvas.draw()
    time.sleep(0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from NB_Modules import *

[placed, original] = coverage(5,5,5)

# %%
print placed
print original
print coverage_area(placed)
# Out:
# [Starting Coord:(4, 4), Width :1, Height:1, Starting Coord:(3, 1), Width :2, Height:1, Starting Coord:(1, 3), Width :2, Height:2, Starting Coord:(3, 3), Width :1, Height:1, None]
# [Starting Coord:(4, 4), Width :1, Height:1, Starting Coord:(3, 1), Width :2, Height:1, Starting Coord:(1, 3), Width :2, Height:2, Starting Coord:(3, 3), Width :1, Height:1, Starting Coord:(2, 3), Width :1, Height:1]
# 8

# %%
rects = get_rects(placed)
og_rects = get_rects(original)
fig,ax = plt.subplots(1)
plt.axis([0,5,0,5])
ax.add_patch(rects[0])
fig.canvas.draw()
for i in range(1,len(rects)):
    time.sleep(0.5)
    ax.add_patch(og_rects[i])
    fig.canvas.draw()
    if placed[i] is None:
        time.sleep(0.5)
        og_rects[i].remove()
    elif not placed[i] == original[i]:
        time.sleep(0.5)
        og_rects[i].remove()
        fig.canvas.draw()
        if rects[i] != None:
            ax.add_patch(rects[i])
            fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print og_rects[1]
print rects[1]
